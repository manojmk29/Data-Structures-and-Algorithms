# %%
#a
from functools import lru_cache
class Solution:
    def numDecodings(self, s: str) -> int:
        n=len(s)
        dp=[-1 for i in range(n+1)]
        dp[n]=1
        for ind in range(n-1,-1,-1):
            if(s[ind]=="0"):
                dp[ind]=0
            else:
                tot=0
                tot+=dp[ind+1]
                if(ind+1<n):
                    if(s[ind]=="1" or ( s[ind]=="2" and s[ind+1]<"7")):
                        tot+=dp[ind+2]
                dp[ind]=tot
        return(dp[0])

# %%
#a
from functools import lru_cache
class Solution:
    def numDecodings(self, s: str) -> int:
        n=len(s)
        dp=[-1 for i in range(n+1)]
        dp[n]=1
        def helper(ind):
            if(dp[ind]!=-1):
                return(dp[ind])
            if(s[ind]=="0"):
                dp[ind]=0
                return(0)
            tot=0
            tot+=helper(ind+1)
            if(ind+1<n):
                if(s[ind]=="1" or ( s[ind]=="2" and s[ind+1]<"7")):
                    tot+=helper(ind+2)
            dp[ind]=tot
            return(tot)
        return(helper(0))

# %%
class Solution:
    def numDecodings(self, s: str) -> int:
        n=len(s)
        def helper(ind,c):
            if(n-1==ind):
                if(c==1):
                    if(s[ind-1]=="0"):
                        return(0)
                    if(s[ind-1]=="2" and s[ind]<"7"):
                        return(1)
                    if(s[ind-1]<"2"):
                        return(1)
                    return(0)
                elif(c==0):
                    if(s[ind]=="0"):
                        return(0)
                    else:
                        return(1)
            if(s[ind]=="0" and c==0):
                return(0)
            tot=0
            if(s[ind]=="0" or s[ind]>"2"):
                tot+=helper(ind+1,0)
            else:
                tot+=helper(ind+1,0)
                tot+=helper(ind+1,1)
            return(tot)
        return(helper(0,0))

# %%
Solution().numDecodings("226")
# Out:
# 4

# %%
from functools import lru_cache
class Solution:
    def numDecodings(self, s: str) -> int:
        n=len(s)
        @lru_cache
        def helper(ind,c):
            if(n-1==ind):
                if(c==1):
                    if(s[ind-1]=="0"):
                        return(0)
                    if(s[ind-1]=="2" and s[ind]<"7"):
                        return(1)
                    if(s[ind-1]<"2"):
                        return(1)
                    return(0)
                elif(c==0):
                    if(s[ind]=="0"):
                        return(0)
                    else:
                        return(1)
            if(c==1):
                if(s[ind-1]=="0"):
                    return(0)
                if(s[ind-1]=="2" and s[ind]>"6"):
                    return(0)
            if(s[ind]=="0" and c==0):
                return(0)
            tot=0
            if(s[ind]=="0" or s[ind]>"2"):
                tot+=helper(ind+1,0)
            else:
                tot+=helper(ind+1,0)
                if(c!=1):
                    tot+=helper(ind+1,1)
            return(tot)
        return(helper(0,0))

# %%
Solution().numDecodings("1201234")
# Out:
# 3

# %%
from functools import lru_cache
class Solution:
    @lru_cache(None)
    def numDecodings(self, s: str) -> int:
        n=len(s)
        def helper(ind):
            if(ind==n):
                return(1)
            if(s[ind]=="0"):
                return(0)
            tot=0
            tot+=helper(ind+1)
            if(ind+1 < n):
                if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
                    tot+=helper(ind+2)
            return(tot)
        return(helper(0))

# %%
Solution().numDecodings("111111111111111111111111111111111111111111111")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13852/1138905460.py in <module>
# ----> 1 Solution().numDecodings("111111111111111111111111111111111111111111111")
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in numDecodings(self, s)
#      15                     tot+=helper(ind+2)
#      16             return(tot)
# ---> 17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
# ---> 15                     tot+=helper(ind+2)
#      16             return(tot)
#      17         return(helper(0))
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#      10                 return(0)
#      11             tot=0
# ---> 12             tot+=helper(ind+1)
#      13             if(ind+1 < n):
#      14                 if(s[ind]=="1" or (s[ind]=="2" and s[ind+1]<"7")):
#
# ~\AppData\Local\Temp/ipykernel_13852/1687802039.py in helper(ind)
#       5         n=len(s)
#       6         def helper(ind):
# ----> 7             if(ind==n):
#       8                 return(1)
#       9             if(s[ind]=="0"):
#
# KeyboardInterrupt:
